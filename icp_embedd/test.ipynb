# %%
import pandas as pd

# %%
df = pd.read_csv('/media/prince/5A4E832F4E83034D/Rocketsteer/REST_API/icp_embedd/titles.csv')

# %%
df2 = df.iloc[:75]

# %%
df2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   75 non-null     str
# dtypes: str(1)
# memory usage: 732.0 bytes

# %%
df2.to_csv('sample2.csv', index=False)

# %%
df2.head()
# Out:
#                        title
# 0                    Founder
# 1                 Co-Founder
# 2                      Owner
# 3                   Co-Owner
# 4  Entrepreneur in Residence
